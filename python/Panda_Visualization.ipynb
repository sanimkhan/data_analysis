# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = '/Users/sanimkhan/Projects/my-git/data_analysis/python/data/Ice Cream Ratings.csv'
df = pd.read_csv(file)

df = df.set_index('Date')

df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-dark-palette')
df1.plot(figsize=(9, 3))
# Out:
# <Axes: xlabel='Date'>

# %%
# Y col specified view
df = pd.read_csv(file)

df.plot(x='Date', y=['Flavor Rating', 'Texture Rating'], kind='line', 
        title='Ice Cream Ratings Over Time', xlabel='Date', ylabel='Rating', figsize=(9, 3))
# Out:
# <Axes: title={'center': 'Ice Cream Ratings Over Time'}, xlabel='Date', ylabel='Rating'>

# %%
# Default view
df = pd.read_csv(file)

df.plot(kind='line', figsize=(9, 3), 
        title='Ice Cream Ratings Over Time', xlabel='Date', ylabel='Rating')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings Over Time'}, xlabel='Date', ylabel='Rating'>

# %%
# Calculate the mean of each rating type
mean_ratings = df[['Flavor Rating', 'Texture Rating', 'Overall Rating']].mean()

# Bar plot for average ratings
mean_ratings.plot(kind='bar', figsize=(9, 3))
# Out:
# <Axes: >

# %%
# Histogram for Overall Rating
df['Overall Rating'].plot(kind='hist', bins=20, edgecolor='black', figsize=(9, 3))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins=20, figsize=(9, 3))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Scatter plot for Flavor Rating vs. Texture Rating
df.plot(kind='scatter', x='Flavor Rating', y='Texture Rating')
# Out:
# <Axes: xlabel='Flavor Rating', ylabel='Texture Rating'>

# %%
# Box plot for all ratings
df[['Flavor Rating', 'Texture Rating', 'Overall Rating']].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Flavor Rating'].plot(kind='hist')
plt.show()

# %%
grouped = df.groupby(['Flavor Rating', 'Texture Rating']).sum().unstack()

# Plotting
grouped.plot(kind='bar')
plt.show()

# %%
df.groupby('Date')['Flavor Rating'].sum().plot(kind='area')
plt.show()
